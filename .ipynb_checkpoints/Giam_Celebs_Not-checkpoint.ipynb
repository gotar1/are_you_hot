# %%
import pandas as pd

# %%
celeb_dict = [
    {
        'Name': 'Clint Howard',
        'Sex': 'Male',
        'DOB': '4/20/1959',
        'Birth Year': 1959,
        'Eye Color': 'Blue',
        'Hair Color': 'Gray',
        'Distinctive Features': 'Teeth',
        'Height(ft)': 5.7,
        'Weight(lbs)': 165.0,
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Linda Hunt',
        'Sex': 'Female',
        'DOB': '04/02/1945',
        'Birth Year': 1945,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Height',
        'Height(ft)': 4.9,
        'Weight(lbs)': 143.0,
        'Zodiac Sign': 'Aquarius',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Mick Jagger',
        'Sex': 'Male',
        'DOB': '07/26/1943', 
        'Birth Year': 1943,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Lips',
        'Height(ft)': 5.10,
        'Weight(lbs)': 161.0,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Jay-Z',
        'Sex': 'Male',
        'DOB': '12/04/1969',
        'Birth Year': 1969,
        'Eye Color': 'Black',
        'Hair Color': 'Black',
        'Distinctive Features': 'Lips',
        'Height(ft)': 6.2,
        'Weight(lbs)': 183.0,
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'Yes',
        'Hot test': 1
    },

    {
        'Name': 'Caitlyn Jenner',
        'Sex': 'Female',
        'DOB': '10/28/1949',
        'Birth Year': 1949,
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Muscular',
        'Height(ft)': 6.2,
        'Weight(lbs)': 194.0,
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Caleb Landry Jones',
        'Sex': 'Male',
        'DOB': '12/07/1989',
        'Birth Year': 1989,
        'Eye Color': 'Blue',
        'Hair Color': 'Red',
        'Distinctive Features': 'Cheekbones',
        'Height(ft)': 5.11,
        'Weight(lbs)': 143.0,
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Kelis',
        'Sex': 'Female',
        'DOB': '08/21/1979',
        'Birth Year': 1979,
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': 5.9,
        'Weight(lbs)': 139.0,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'Yes',
        'Hot test': 1
    },

    {
        'Name': 'Barry Keoghan',
        'Sex': 'Male',
        'DOB': '10/18/1992',
        'Birth Year': 1992,
        'Eye Color': 'Blue',
        'Hair Color': 'Black',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 5.6, 
        'Weight(lbs)': 159.0,
        'Zodiac Sign': 'Libra',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Wiz Khalifa',
        'Sex': 'Male',
        'DOB': '09/08/1987',
        'Birth Year': 1987,
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Teeth',
        'Height(ft)': 6.4,
        'Weight(lbs)': 172,
        'Zodiac Sign': 'Virgo',
        'Tattoo Body Art': 'Yes',
        'Hot test': 1
    },

    {
        'Name': 'Salman Khan',
        'Sex': 'Male',
        'DOB': '12/27/1965',
        'Birth Year': 1965,
        'Eye Color': 'Brown' ,
        'Hair Color': 'Black',
        'Distinctive Features': 'Muscular',
        'Height(ft)': 5.8,
        'Weight(lbs)': 194,
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Stephen King',
        'Sex': 'Male',
        'DOB': '09/21/1947',
        'Birth Year': 1947,
        'Eye Color': 'Blue',
        'Hair Color': 'Gray',
        'Distinctive Features': 'Lips',
        'Height(ft)': 6.4,
        'Weight(lbs)': 165.0,
        'Zodiac Sign': 'Virgo',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Lisa Lampanelli',
        'Sex': 'Female',
        'DOB': '07/19/1961',
        'Birth Year': 1961,
        'Eye Color': 'Brown',
        'Hair Color': 'Blond',
        'Distinctive Features': 'Chin' ,
        'Height(ft)': 5.7,
        'Weight(lbs)': 141.0,
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'Yes',
        'Hot test': 1
    },

    {
        'Name': 'Tomas Lemarquis',
        'Sex': 'Male',
        'DOB': '08/03/1977',
        'Birth Year': 1977,
        'Eye Color': 'Blue',
        'Hair Color': 'Bald',
        'Distinctive Features': "Skin",
        'Height(ft)': 5.9,
        'Weight(lbs)': 174.0, 
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'Yes',
        'Hot test': 1
    },

    {
        'Name': 'Amanda Lepore',
        'Sex': 'Female',
        'DOB': '11/21/1967',
        'Birth Year': 1967,
        'Eye Color': 'Brown',
        'Hair Color': 'Blond',
        'Distinctive Features': 'Lips',
        'Height(ft)': 5.2,
        'Weight(lbs)': 110.0,
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Lorde',
        'Sex': 'Female',
        'DOB': '11/07/1996',
        'Birth Year': 1996,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': 5.5,
        'Weight(lbs)': 134.0,
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Lyle Lovett',
        'Sex': 'Male',
        'DOB': '11/1/1957',
        'Birth Year': 1957,
        'Eye Color': 'Brown' ,
        'Hair Color': 'Blond',
        'Distinctive Features': 'Lips',
        'Height(ft)': 6.0,
        'Weight(lbs)': 171.0,
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Matt Lucas',
        'Sex': 'Male',
        'DOB': '05/05/1974',
        'Birth Year': 1974,
        'Eye Color': 'Hazel',
        'Hair Color': 'Bald',
        'Distinctive Features': 'Skin',
        'Height(ft)': 5.6,
        'Weight(lbs)': 185.0,
        'Zodiac Sign': 'Pisces',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Shane Macgowan',
        'Sex': 'Male',
        'DOB': '12/25/1957',
        'Birth Year': 1957,
        'Eye Color': 'Blue',
        'Hair Color': 'Gray',
        'Distinctive Features': 'Teeth',
        'Height(ft)': 5.9, 
        'Weight(lbs)': 115.0,
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'William H Macy',
        'Sex': 'Male',
        'DOB': '03/13/1950', 
        'Birth Year': 1950,
        'Eye Color': 'Green',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Smile',
        'Height(ft)': 5.8,
        'Weight(lbs)': 159.0,
        'Zodiac Sign': 'Pisces',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'John Malkovich',
        'Sex': 'Male',
        'DOB': '12/9/1953',
        'Birth Year': 1953,
        'Eye Color': 'Hazel',
        'Hair Color': 'Gray',
        'Distinctive Features': 'Chin',
        'Height(ft)': 6.0,
        'Weight(lbs)': 172.0,
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Marilyn Manson',
        'Sex': 'Male',
        'DOB': '01/05/1969',
        'Birth Year': 1969,
        'Eye Color': 'Hazel',
        'Hair Color': 'Black',
        'Distinctive Features': 'Lips',
        'Height(ft)': 6.1,
        'Weight(lbs)': 181.0,
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Biz Markie',
        'Sex': 'Male',
        'DOB': '04/08/1964',
        'Birth Year': 1964,
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Teeth',
        'Height(ft)': 6.3,
        'Weight(lbs)': 220.0,
        'Zodiac Sign': 'Aries',
        'Tattoo Body Art': 'Yes',
        'Hot test': 1
    },

    {
        'Name': 'Eddie Marsan',
        'Sex': 'Male',
        'DOB': '06/09/1968',
        'Birth Year': 1968,
        'Eye Color': 'Green',
        'Hair Color': 'Gray',
        'Distinctive Features': 'Cheeks',
        'Height(ft)': 5.8,
        'Weight(lbs)': 150.0,
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name': 'Heather Matarazzo',
        'Sex': 'Female',
        'DOB': '11/10/1982',
        'Birth Year': 1982,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Teeth',
        'Height(ft)': 5.4,
        'Weight(lbs)': 121.0,
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

    {
        'Name':  'Jack McBrayer',
        'Sex': 'Male',
        'DOB': '05/27/1973',
        'Birth Year': 1973,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Smile',
        'Height(ft)': 5.10,
        'Weight(lbs)': 172.0,
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art': 'No',
        'Hot test': 1
    },

]

celeb_df = pd.DataFrame.from_dict(celeb_dict)  
celeb_df.head(2)
# Out:
#            Name     Sex         DOB  Birth Year Eye Color Hair Color  \
# 0  Clint Howard    Male   4/20/1959        1959      Blue       Gray
# 1    Linda Hunt  Female  04/02/1945        1945      Blue      Brown
#
#   Distinctive Features  Height(ft)  Weight(lbs) Zodiac Sign Tattoo Body Art  \
# 0                Teeth         5.7        165.0      Taurus              No
# 1               Height         4.9        143.0    Aquarius              No
#
#    Hot test
# 0         1
# 1         1

# %%
celeb_df.to_csv("giam_celebs_not.csv")
