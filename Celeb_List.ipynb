# %%
import pandas as pd

# %%
celeb_dict = [
    {
        'Name': 'Rachel Weisz',
        'Sex': 'Female',
        'DOB': '03/07/1970',
        'Birth Year': '1970',
        'Eye Color': 'Hazel',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.6',
        'Weight(lbs)': '125.0',
        'Zodiac Sign': 'Pisces',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Robert Pattinson',
        'Sex': 'Male',
        'DOB': '05/13/1986',
        'Birth Year': '1986',
        'Eye Color':'Blue',
        'Hair Color':'Brown' ,
        'Distinctive Features':'Eyebrows',
        'Height(ft)': '6.0',
        'Weight(lbs)': '165.0',
        'Zodiac Sign': 'Tarus',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Monica Bellucci',
        'Sex': 'Female',
        'DOB': '09/30/1964',
        'Birth Year': '1964',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Face',
        'Height(ft)': '5.7',
        'Weight(lbs)': '140.0',
        'Zodiac Sign': 'Libra',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Jake Gyllenhaal',
        'Sex': 'Male',
        'DOB': '12/19/1980',
        'Birth Year': '1980',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '5.11',
        'Weight(lbs)': '171',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Angela Bassett',
        'Sex': 'Female',
        'DOB': '8/16/1958',
        'Birth Year': '1958',
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Smile' ,
        'Height(ft)': '5.3',
        'Weight(lbs)': '134.0',
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Armie Hammer',
        'Sex': 'Male',
        'DOB': '8/28/1986',
        'Birth Year': '1986',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Height',
        'Height(ft)': '6.5',
        'Weight(lbs)': '207.0',
        'Zodiac Sign': 'Virgo',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Marion Cotillard',
        'Sex': 'Female',
        'DOB': '9/30/1975',
        'Birth Year': '1975',
        'Eye Color':'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Mole',
        'Height(ft)': '5.6',
        'Weight(lbs)': '126.0',
        'Zodiac Sign': 'Libra'
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Idris Elba',
        'Sex': 'Male',
        'DOB': '9/6/1972',
        'Birth Year': '1972',
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Accent',
        'Height(ft)': '6.2', 
        'Weight(lbs)': '211.0',
        'Zodiac Sign': 'Virgo',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Hailee Steinfeld',
        'Sex': 'Female',
        'DOB': '12/11/1996,
        'Birth Year': '1996',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.6',
        'Weight(lbs)': '130',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'John Stamos',
        'Sex': 'Male',
        'DOB': '8/9/1963',
        'Birth Year': '1963',
        'Eye Color': 'Blue',
        'Hair Color':'Brown',
        'Distinctive Features': 'Smile',
        'Height(ft)': '6.0',
        'Weight(lbs)': '174.0',
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Anna Popplewell',
        'Sex': 'Female',
        'DOB': '12/16/1988',
        'Birth Year': '1988',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Lips',
        'Height(ft)': '5.3',
        'Weight(lbs)': '119.0',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Tyler Blackburn',
        'Sex': 'Male',
        'DOB': '10/12/1986',
        'Birth Year': '1986',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.10',
        'Weight(lbs)': '157.0',
        'Zodiac Sign': 'Libra',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'AnnaSophia Robb',
        'Sex': 'Female',
        'DOB': '12/08/1993',
        'Birth Year': '1993',
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Eyes' ,
        'Height(ft)': '5.0',
        'Weight(lbs)': '108.0', 
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Bradley Cooper',
        'Sex': 'Male',
        'DOB': '1/5/1975',
        'Birth Year': '1975',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '6.1',
        'Weight(lbs)': '183.0',
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Nicole Kidman',
        'Sex': 'Female',
        'DOB': '6/20/1967',
        'Birth Year': '1967',
        'Eye Color': 'Blue',
        'Hair Color': 'Red',
        'Distinctive Features': 'Statuesque',
        'Height(ft)': '5.11',
        'Weight(lbs)': '140.0',
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Tom Welling',
        'Sex': 'Male',
        'DOB': '4/26/1977',
        'Birth Year': '1977',
        'Eye Color': 'Blue' ,
        'Hair Color': 'Brown',
        'Distinctive Features': 'Jawline' ,
        'Height(ft)': '6.2',
        'Weight(lbs)': '198.0',
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Mercedes Mason',
        'Sex': 'Female',
        'DOB': '1/13/1983',
        'Birth Year': '1983',
        'Eye Color': "Blue",
        'Hair Color': "Brown",
        'Distinctive Features': 'Smile',
        'Height(ft)': '5.3',
        'Weight(lbs)': '126.0',
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art': 'Yes',
        'Hot test': '0'
    },

    {
        'Name': 'Jesse Williams',
        'Sex': 'Male',
        'DOB': '11/6/1981',
        'Birth Year': '1981',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Looks',
        'Height(ft)': '5.11', 
        'Weight(lbs)': '175.0',
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'Yes',
        'Hot test': '0'
    },

    {
        'Name': 'Kristen Stewart',
        'Sex': 'Female',
        'DOB': '4/21/1990', 
        'Birth Year': '1990',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '5.06',
        'Weight(lbs)': '133.0',
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Joe Manganiello',
        'Sex': 'Male',
        'DOB': '10/24/1976',
        'Birth Year': '1976',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Body',
        'Height(ft)': '6.1'
        'Weight(lbs)': '205.0',
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Julianne Moore',
        'Sex': 'Female',
        'DOB': '7/3/1960',
        'Birth Year': '1960',
        'Eye Color': 'Blue',
        'Hair Color': 'Red',
        'Distinctive Features': 'Smile',
        'Height(ft)': '5.3',
        'Weight(lbs)': '128.0',
        'Zodiac Sign': 'Cancer',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'John Boyega',
        'Sex': 'Male',
        'DOB': '12/17/1992',
        'Birth Year': '1992',
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Build',
        'Height(ft)': '5.10',
        'Weight(lbs)': '179.0',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'Yes',
        'Hot test': '0'
    },

    {
        'Name': 'Kate Winslet',
        'Sex': 'Female',
        'DOB': '10/5/1975',
        'Birth Year': '1975',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Smile',
        'Height(ft)': '5.6',
        'Weight(lbs)': '139.0',
        'Zodiac Sign': 'Libra',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Garrett Hedlund',
        'Sex': 'Male',
        'DOB': '9/3/1984',
        'Birth Year': '1984',
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '6.2',
        'Weight(lbs)': '201.0',
        'Zodiac Sign': 'Virgo',
        'Tattoo Body Art': 'No',
        'Hot test': '0'
    },

    {
        'Name': 'Jennifer Aniston',
        'Sex': 'Female',
        'DOB': '2/11/1969',
        'Birth Year': '1969',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.4',
        'Weight(lbs)': '117.0',
        'Zodiac Sign': 'Aquarius',
        'Tattoo Body Art':'No',
        'Hot test': '0',
    },
    
    {
        'Name': 'Jack McBrayer',
        'Sex': 'Male',
        'DOB': '7/19/1976',
        'Birth Year': '1976',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '6.0',
        'Weight(lbs)': '172.0',
        'Zodiac Sign': 'Cancer',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Ozzy Osbourne',
        'Sex': 'Male',
        'DOB': '6/3/1953',
        'Birth Year': '1953',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.4',
        'Weight(lbs)': '132.0',
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art':'Yes',
        'Hot test': '1',
    },
    
    {
        'Name': 'Kate Micucci',
        'Sex': 'Female',
        'DOB': '4/10/1983',
        'Birth Year': '1983',
        'Eye Color': 'Black',
        'Hair Color': 'Black'
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.4',
        'Weight(lbs)': '145.0',
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Haley Joel Osment',
        'Sex': 'Male',
        'DOB': '12/1/1985',
        'Birth Year': '1985',
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.4',
        'Weight(lbs)': '148.0',
        'Zodiac Sign': 'Sagitarius',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Sarah Jessica Parker',
        'Sex': 'Female',
        'DOB': '8/10/1965',
        'Birth Year': '1965',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.5',
        'Weight(lbs)': '125.0',
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Camilla Parker-Bowles',
        'Sex': 'Female',
        'DOB': '6/6/1947',
        'Birth Year': '1947',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.5',
        'Weight(lbs)': '146.0',
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Pedro Pascal',
        'Sex': 'Male',
        'DOB': '1/31/1975',
        'Birth Year': '1975',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '5.8',
        'Weight(lbs)': '165.0',
        'Zodiac Sign': 'Aquarius',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Logan Paul',
        'Sex': 'Male',
        'DOB': '3/11/1994',
        'Birth Year': '1994',
        'Eye Color': 'Blue',
        'Hair Color': 'BLonde',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '6.0',
        'Weight(lbs)': '185.0',
        'Zodiac Sign': 'Picses',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Ron Perlman',
        'Sex': 'Male',
        'DOB': '9/4/1953',
        'Birth Year': '1953',
        'Eye Color': 'Blue',
        'Hair Color': 'White',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '5.11',
        'Weight(lbs)': '175.0',
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Michael Phelps',
        'Sex': 'Male',
        'DOB': '6/6/1965',
        'Birth Year': '1965',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Body',
        'Height(ft)': '6.1',
        'Weight(lbs)': '155.0',
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art':'Yes',
        'Hot test': '1',
    },
    
    {
        'Name': 'Jesse Plemons',
        'Sex': 'Male',
        'DOB': '4/1/1988',
        'Birth Year': '1988',
        'Eye Color': 'Brown',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.10',
        'Weight(lbs)': '160.0',
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Iggy Pop',
        'Sex': 'Male',
        'DOB': '7/23/1951',
        'Birth Year': '1951',
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '6.0',
        'Weight(lbs)': '172.0',
        'Zodiac Sign': 'Cancer',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Randy Quaid',
        'Sex': 'Male',
        'DOB': '4/13/1957',
        'Birth Year': '1957',
        'Eye Color': 'Blue',
        'Hair Color': 'Red',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '6.1',
        'Weight(lbs)': '225.0',
        'Zodiac Sign': 'Aries',
        'Tattoo Body Art':'Yes',
        'Hot test': '1',
    },
    
    {
        'Name': 'John C. Reilly',
        'Sex': 'Male',
        'DOB': '12/13/1965',
        'Birth Year': '1965',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.11',
        'Weight(lbs)': '190.0',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Giovanni Ribisi',
        'Sex': 'Male',
        'DOB': '6/29/1974',
        'Birth Year': '1974',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '5.7',
        'Weight(lbs)': '160.0',
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Kid Rock',
        'Sex': 'Male',
        'DOB': '11/23/1966',
        'Birth Year': '1966',
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '6.1',
        'Weight(lbs)': '177.0',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Dennis Rodman',
        'Sex': 'Male',
        'DOB': '7/7/1961',
        'Birth Year': '1961',
        'Eye Color': 'Black',
        'Hair Color': 'Black',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '6.3',
        'Weight(lbs)': '220.0',
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art':'Yes',
        'Hot test': '1',
    },
    
    {
        'Name': 'Mickey Rourke',
        'Sex': 'Male',
        'DOB': '3/19/1947',
        'Birth Year': '1947',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '5.10',
        'Weight(lbs)': '198.0',
        'Zodiac Sign': 'Pisces',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Geoffrey Rush',
        'Sex': 'Male',
        'DOB': '11/1/1942',
        'Birth Year': '1942',
        'Eye Color': 'Blue',
        'Hair Color': 'White',
        'Distinctive Features': 'Face',
        'Height(ft)': '5.10',
        'Weight(lbs)': '150.0',
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Paul Rust',
        'Sex': 'Male',
        'DOB': '8/26/1980',
        'Birth Year': '1980',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.7',
        'Weight(lbs)': '155.0',
        'Zodiac Sign': 'Virgo',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Kristen Schaal',
        'Sex': 'Female',
        'DOB': '10/11/1978',
        'Birth Year': '1978',
        'Eye Color': 'Blue',
        'Hair Color': 'Red',
        'Distinctive Features': 'Eyes',
        'Height(ft)': '5.6',
        'Weight(lbs)': '140.0',
        'Zodiac Sign': 'Libra',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Steven Seagal',
        'Sex': 'Male',
        'DOB': '11/23/1952',
        'Birth Year': '1952',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Smile',
        'Height(ft)': '5.11',
        'Weight(lbs)': '215.0',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Seal',
        'Sex': 'Male',
        'DOB': '7/22/1963',
        'Birth Year': '1963',
        'Eye Color': 'Black',
        'Hair Color': 'Bald',
        'Distinctive Features': 'Face',
        'Height(ft)': '5.10',
        'Weight(lbs)': '165.0',
        'Zodiac Sign': 'Cancer',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Charlie Sheen',
        'Sex': 'Male',
        'DOB': '12/27/1965',
        'Birth Year': '1965',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': '6.0',
        'Weight(lbs)': '180.0',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art':'Yes',
        'Hot test': '1',
    },
    
    {
        'Name': 'Gabourey Sidibe',
        'Sex': 'Female',
        'DOB': '7/25/1983',
        'Birth Year': '1983',
        'Eye Color': 'Black',
        'Hair Color': 'Black',
        'Distinctive Features': 'Smile',
        'Height(ft)': '5.10',
        'Weight(lbs)': '290.0',
        'Zodiac Sign': 'Cancer',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
    
    {
        'Name': 'Matt Smith',
        'Sex': 'Male',
        'DOB': '7/19/1982',
        'Birth Year': '1982',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': '5.9',
        'Weight(lbs)': '159.0',
        'Zodiac Sign': 'Cancer',
        'Tattoo Body Art':'No',
        'Hot test': '1',
    },
]


celeb_df = pd.DataFrame.from_dict(celeb_dict)  
celeb_df
# Out:
#   File "<ipython-input-1-7ea0af08dfb6>", line 103
#     'Tattoo Body Art': 'No',
#                      ^
# SyntaxError: invalid syntax
