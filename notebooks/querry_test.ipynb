# %%
import pandas as pd 
import requests

# %%
url = 'http://127.0.0.1:5000/api/v1.0/hot'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data
# Out:
# [{'Name': 'Kerry Washington',
#   'Sex': 'Female',
#   'DOB': '01/31/1977',
#   'Birth Year': 1977,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Black',
#   'Distinctive Features': 'Lips',
#   'Height(ft)': 5.4,
#   'Weight(lbs)': 117.0,
#   'Zodiac Sign': 'Aquarius',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Jensen Ackles',
#   'Sex': 'Male',
#   'DOB': '03/01/1978',
#   'Birth Year': 1978,
#   'Eye Color': 'Green',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 6.1,
#   'Weight(lbs)': 183.0,
#   'Zodiac Sign': 'Pisces',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Shay Mitchell ',
#   'Sex': 'Female',
#   'DOB': '04/10/1987',
#   'Birth Year': 1987,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Black',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 132.0,
#   'Zodiac Sign': 'Aries',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Ian Somerhalder',
#   'Sex': 'Male',
#   'DOB': '12/08/1978',
#   'Birth Year': 1978,
# ...
