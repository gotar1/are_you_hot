# %%
import pandas as pd

# %%
celeb_dict = [
    {
        'Name': 'Kerry Washington',
        'Sex': 'Female',
        'DOB': '01/31/1977',
        'Birth Year': 1977,
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Lips',
        'Height(ft)': 5.4,
        'Weight(lbs)': 117.0,
        'Zodiac Sign': 'Aquarius',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Jensen Ackles',
        'Sex': 'Male',
        'DOB': '03/01/1978',
        'Birth Year': 1978,
        'Eye Color': 'Green',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 6.1,
        'Weight(lbs)': 183.0,
        'Zodiac Sign': 'Pisces',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Shay Mitchell ',
        'Sex': 'Female',
        'DOB': '04/10/1987',
        'Birth Year': 1987,
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Hair',
        'Height(ft)': 5.7,
        'Weight(lbs)': 132.0,
        'Zodiac Sign': 'Aries',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Ian Somerhalder',
        'Sex': 'Male',
        'DOB': '12/08/1978',
        'Birth Year': 1978,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 5.9,
        'Weight(lbs)': 165.5,
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Alycia Debnam-Carey',
        'Sex': 'Female',
        'DOB': '07/20/1993',
        'Birth Year': 1993,
        'Eye Color': 'Green',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Lips',
        'Height(ft)': 5.7,
        'Weight(lbs)': 121.0,
        'Zodiac Sign': 'Cancer',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Ryan Gosling',
        'Sex': 'Male',
        'DOB': '11/12/1980',
        'Birth Year': 1980,
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Jawline',
        'Height(ft)': 6.0,
        'Weight(lbs)': 172.0,
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Ruby Rose',
        'Sex': 'Female',
        'DOB': '03/20/1986',
        'Birth Year': 1986,
        'Eye Color': 'Green',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 5.7,
        'Weight(lbs)': 128.0,
        'Zodiac Sign': 'Pisces',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Ashton Kutcher',
        'Sex': 'MAle',
        'DOB': '02/07/1978',
        'Birth Year': 1978,
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Jawline',
        'Height(ft)': 6.2, 
        'Weight(lbs)': 176.0,
        'Zodiac Sign': 'Aquarius',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Kate Upton',
        'Sex': 'Female',
        'DOB': '07/10/1992',
        'Birth Year': 1992,
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Lips',
        'Height(ft)': 5.10,
        'Weight(lbs)': 156.5,
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Ricky Whittle',
        'Sex': 'Male',
        'DOB': '12/31/1981',
        'Birth Year': 1981,
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Muscular',
        'Height(ft)': 6.1,
        'Weight(lbs)': 200.5,
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Jessica Biel',
        'Sex': 'Female',
        'DOB': '03/03/1982',
        'Birth Year': 1982,
        'Eye Color': 'Hazel',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 5.7,
        'Weight(lbs)': 121.0,
        'Zodiac Sign': 'Pisces',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Jason Momoa',
        'Sex': 'male',
        'DOB': '08/01/1979',
        'Birth Year': 1979,
        'Eye Color': 'Green',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Muscular',
        'Height(ft)': 6.4,
        'Weight(lbs)': 234.0,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Marie Avgeropoulos',
        'Sex': 'Female',
        'DOB': '06/17/1986',
        'Birth Year': 1986,
        'Eye Color': 'Green',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 5.5,
        'Weight(lbs)': 121.0, 
        'Zodiac Sign': ' Gemini',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Stephen Amell',
        'Sex': 'Male',
        'DOB': '05/08/1981',
        'Birth Year': 1981,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Muscular',
        'Height(ft)': 6.1,
        'Weight(lbs)': 182.0,
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Kate Hudson',
        'Sex': 'Female',
        'DOB': '04/19/1979',
        'Birth Year': 1979,
        'Eye Color': 'Green',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Hair',
        'Height(ft)': 5.6,
        'Weight(lbs)': 121.0,
        'Zodiac Sign': 'Aries',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Chace Crawford',
        'Sex': 'Male',
        'DOB': '07/18/1985',
        'Birth Year': 1985,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 6.0,
        'Weight(lbs)': 175.0,
        'Zodiac Sign': 'Cancer',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Olivia Wilde',
        'Sex': 'Female',
        'DOB': '03/10/1984',
        'Birth Year': 1984,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 5.7,
        'Weight(lbs)': 115.0,
        'Zodiac Sign': 'Pisces',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Michael Fassbender',
        'Sex': 'Male',
        'DOB': '04/02/1977',
        'Birth Year': 1977,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Jawline',
        'Height(ft)': 6.0, 
        'Weight(lbs)': 174.0,
        'Zodiac Sign': 'Aries',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Daisy Ridley',
        'Sex': 'Female',
        'DOB': '04/10/1992',
        'Birth Year': 1992,
        'Eye Color': 'Hazel',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 5.7,
        'Weight(lbs)': 121.0,
        'Zodiac Sign': 'Aries',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Chris Pine',
        'Sex': 'Male',
        'DOB': '08/26/1980',
        'Birth Year': 1980,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 6.0,
        'Weight(lbs)': 172.0,
        'Zodiac Sign': 'Virgo',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Cate Blanchett',
        'Sex': 'Female',
        'DOB': '05/14/1969',
        'Birth Year': 1969,
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Cheekbones',
        'Height(ft)': 5.8,
        'Weight(lbs)': 130.0,
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Gerard Butler',
        'Sex': 'Male',
        'DOB': '11/13/1969',
        'Birth Year': 1969,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Hair',
        'Height(ft)': 6.2,
        'Weight(lbs)': 187.5,
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Emma Watson',
        'Sex': 'Female',
        'DOB': '04/15/1990',
        'Birth Year': 1990,
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes', 
        'Height(ft)': 5.5,
        'Weight(lbs)': 117.0,
        'Zodiac Sign': 'Aries',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Luke Evans',
        'Sex': 'Male',
        'DOB': '04/15/1979',
        'Birth Year': 1979,
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Personality',
        'Height(ft)': 6.0,
        'Weight(lbs)': 174.0,
        'Zodiac Sign': 'Aries',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Penélope Cruz',
        'Sex': 'Female',
        'DOB': '04/28/1974',
        'Birth Year': 1974,
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Lips',
        'Height(ft)': 5.6,
        'Weight(lbs)': 137.0,
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Tina Turner',
        'Sex': 'Female',
        'DOB': '11/26/1939',
        'Birth Year': 1939,
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Legs',
        'Height(ft)': 5.4,
        'Weight(lbs)': 129.0,
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Brooke Shields',
        'Sex': 'Female',
        'DOB': '05/31/1965',
        'Birth Year': 1965,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 6.0,
        'Weight(lbs)': 154.0,
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Whitney Houston',
        'Sex': 'Female',
        'DOB': '08/09/1963',
        'Birth Year': 1963,
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Chin',
        'Height(ft)': 5.6,
        'Weight(lbs)': 134.5,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Belinda Carlisle',
        'Sex': 'Female',
        'DOB': '08/17/1958',
        'Birth Year': 1958,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Lips',
        'Height(ft)': 5.7,
        'Weight(lbs)': 137.0,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Lisa Bonet',
        'Sex': 'Female',
        'DOB': '11/16/1967',
        'Birth Year': 1967,
        'Eye Color': 'Black',
        'Hair Color': 'Black',
        'Distinctive Features': 'Hair',
        'Height(ft)': 5.2,
        'Weight(lbs)': 117.0,
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Marilyn Monroe',
        'Sex': 'Female',
        'DOB': '06/01/1926',
        'Birth Year': 1926,
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Hair',
        'Height(ft)': 5.5,
        'Weight(lbs)': 119.0,
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Richard Gere',
        'Sex': 'Male',
        'DOB': '08/31/1949',
        'Birth Year': 1949,
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Nose',
        'Height(ft)': 5.10,
        'Weight(lbs)': 174.0,
        'Zodiac Sign': 'Virgo',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Antonio Bandera',
        'Sex': 'Male',
        'DOB': '08/10/1960',
        'Birth Year': 1960,
        'Eye Color': 'Brown',
        'Hair Color': 'Gray',
        'Distinctive Features': 'Voice',
        'Height(ft)': 5.8,
        'Weight(lbs)': 167.5,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Bill Clinton',
        'Sex': 'Male',
        'DOB': '08/19/1946',
        'Birth Year': 1946,
        'Eye Color': 'Gray',
        'Hair Color': 'Gray',
        'Distinctive Features': 'Voice',
        'Height(ft)': 6.2,
        'Weight(lbs)': 192.0,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Selena Quintanilla',
        'Sex': 'Female',
        'DOB': '04/16/1971',
        'Birth Year': 1971,
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Lips',
        'Height(ft)': 5.5,
        'Weight(lbs)': 126.0,
        'Zodiac Sign': 'Aries',
        'Tattoo Body Art': 'No'
    },

     {
        'Name': 'Angelina Jolie',
        'Sex': 'Female',
        'DOB': '06/04/1975',
        'Birth Year': 1975,
        'Eye Color': 'Gray',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Lips',
        'Height(ft)': 5.6,
        'Weight(lbs)': 119.0,
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Johnny Depp',
        'Sex': 'Male',
        'DOB': '06/09/1963',
        'Birth Year': 1963,
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Cheekbones',
        'Height(ft)': 5.10,
        'Weight(lbs)': 171.0,
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Charlize Theron',
        'Sex': 'Female',
        'DOB': '08/07/1975', 
        'Birth Year': 1975,
        'Eye Color': 'Green',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Attractive',
        'Height(ft)': 5.9,
        'Weight(lbs)': 121.0,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Brad Pitt',
        'Sex': 'Male',
        'DOB': '12/18/1963',
        'Birth Year': 1963,
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Jaw',
        'Height(ft)': 5.11,
        'Weight(lbs)': 172.0,
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Amber Heard',
        'Sex': 'Female',
        'DOB': '04/22/1986',
        'Birth Year': 1986,
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Slim',
        'Height(ft)': 5.7,
        'Weight(lbs)': 137.0,
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Jared Leto',
        'Sex': 'Male',
        'DOB': '12/26/1971',
        'Birth Year': 1971,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 5.9,
        'Weight(lbs)': 152.0,
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Natalie Portman',
        'Sex': 'Female',
        'DOB': '06/09/1981',
        'Birth Year': 1981,
        'Eye Color': 'Hazel',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Moles',
        'Height(ft)': 5.3,
        'Weight(lbs)': 110.0,
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Channing Tatum',
        'Sex': 'Male',
        'DOB': '04/26/1980',
        'Birth Year': 1980,
        'Eye Color': 'Green',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 6.1, 
        'Weight(lbs)': 196.0,
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Mila Kunis',
        'Sex': 'Female',
        'DOB': '08/14/1983',
        'Birth Year': 1983,
        'Eye Color': 'Green and Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Sexy',
        'Height(ft)': 5.4,
        'Weight(lbs)': 115.0,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Chris Hemsworth',
        'Sex': 'Male',
        'DOB': '08/11/1983',
        'Birth Year': 1983,
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Voice',
        'Height(ft)': 6.3,
        'Weight(lbs)': 201.0,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Scarlett Johansson',
        'Sex': 'Female',
        'DOB': '11/22/1984',
        'Birth Year': 1984,
        'Eye Color': 'Green',
        'Hair Color': 'Brunette',
        'Distinctive Features': 'Lips',
        'Height(ft)': 5.3,
        'Weight(lbs)': 125.0,
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Matt Bomer',
        'Sex': 'Male',
        'DOB': '10/11/1977',
        'Birth Year': 1977,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 5.11,
        'Weight(lbs)': 176.0,
        'Zodiac Sign': 'Libra',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Henry Cavill',
        'Sex': 'Male',
        'DOB': '05/05/1983',
        'Birth Year': 1983,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Jawline',
        'Height(ft)': 6.1,
        'Weight(lbs)': 203.0, 
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Gal Gadot',
        'Sex': 'Female',
        'DOB': '04/30/1985',
        'Birth Year': 1985,
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Voice',
        'Height(ft)': 5.10,
        'Weight(lbs)': 141.0,
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Leonardo DiCaprio',
        'Sex': 'Male',
        'DOB': '11/11/1974',
        'Birth Year': 1974,
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Style',
        'Height(ft)': 6.0,
        'Weight(lbs)': 192.0,
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Emilia Clarke',
        'Sex': 'Female',
        'DOB': '10/23/1986',
        'Birth Year': 1986,
        'Eye Color': 'Green',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Lips',
        'Height(ft)': 5.2,
        'Weight(lbs)': 119.0,
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Jude Law',
        'Sex': 'Male',
        'DOB': '12/29/1972',
        'Birth Year': 1972,
        'Eye Color': 'Green',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Voice',
        'Height(ft)': 5.11,
        'Weight(lbs)': 192.0,
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Kate Beckinsale',
        'Sex': 'Female',
        'DOB': '07/26/1973',
        'Birth Year': 1973,
        'Eye Color': 'Hazel',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Slim',
        'Height(ft)': 5.7, 
        'Weight(lbs)': 119.0,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Michael Ealy',
        'Sex': 'Male',
        'DOB': '08/03/1973', 
        'Birth Year': 1973,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Cheekbones',
        'Height(ft)': 5.10,
        'Weight(lbs)': 167.5,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Meagan Good',
        'Sex': 'Female',
        'DOB': '08/08/1981',
        'Birth Year': 1981,
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Eyebrows',
        'Height(ft)': 5.5,
        'Weight(lbs)': 126.0,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Ryan Reynolds',
        'Sex': 'Male',
        'DOB': '10/23/1976',
        'Birth Year': 1976,
        'Eye Color': 'Hazel',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Muscular',
        'Height(ft)': 6.2,
        'Weight(lbs)': 185.0,
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Lucy Hale',
        'Sex': 'Female',
        'DOB': '06/14/1989',
        'Birth Year': 1989,
        'Eye Color': 'Green',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Smile',
        'Height(ft)': 5.2,
        'Weight(lbs)': 108.0,
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Zac Efron',
        'Sex': 'Male',
        'DOB': '10/18/1987',
        'Birth Year': 1987,
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Eyes',
        'Height(ft)': 5.8,
        'Weight(lbs)': 181.0,
        'Zodiac Sign': 'Libra',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Adelaide Kane',
        'Sex': 'Female',
        'DOB': '08/09/1990',
        'Birth Year': 1990,
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Slim',
        'Height(ft)': 5.4,
        'Weight(lbs)': 110.0,
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Chris Pratt',
        'Sex': 'Male',
        'DOB': '06/21/1979',
        'Birth Year': 1979,
        'Eye Color': 'Green',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Height',
        'Height(ft)': 6.2,
        'Weight(lbs)': 223.0,
        'Zodiac Sign': 'Cancer',
        'Tattoo Body Art': 'No'
    },

        {
        'Name': 'Rachel Weisz',
        'Sex': 'Female',
        'DOB': '03/07/1970',
        'Birth Year': '1970',
        'Eye Color': 'Hazel',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Long Brown Hair',
        'Height(ft)': '5.6',
        'Weight(lbs)': '125.0',
        'Zodiac Sign': 'Pisces',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Robert Pattinson',
        'Sex': 'Male',
        'DOB': '05/13/1986',
        'Birth Year': '1986',
        'Eye Color':'Blue',
        'Hair Color':'Brown' ,
        'Distinctive Features':'Thick Eyebrows',
        'Height(ft)': '6.0',
        'Weight(lbs)': '165.0',
        'Zodiac Sign': 'Tarus',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Monica Bellucci',
        'Sex': 'Female',
        'DOB': '09/30/1964',
        'Birth Year': '1964',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Beautifal Face',
        'Height(ft)': '5.7',
        'Weight(lbs)': '140.0',
        'Zodiac Sign': 'Libra',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Jake Gyllenhaal',
        'Sex': 'Male',
        'DOB': '12/19/1980',
        'Birth Year': '1980',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Deep Blue Eyes',
        'Height(ft)': '5.11',
        'Weight(lbs)': '171',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Angela Bassett',
        'Sex': 'Female',
        'DOB': '8/16/1958',
        'Birth Year': '1958',
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Wide Smile' ,
        'Height(ft)': '5.3',
        'Weight(lbs)': '134.0',
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Armie Hammer',
        'Sex': 'Male',
        'DOB': '8/28/1986',
        'Birth Year': '1986',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Towering Height',
        'Height(ft)': '6.5',
        'Weight(lbs)': '207.0',
        'Zodiac Sign': 'Virgo',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Marion Cotillard',
        'Sex': 'Female',
        'DOB': '9/30/1975',
        'Birth Year': '1975',
        'Eye Color':'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Mole on Forehead',
        'Height(ft)': '5.6',
        'Weight(lbs)': '126.0',
        'Zodiac Sign': 'Libra'
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Idris Elba',
        'Sex': 'Male',
        'DOB': '9/6/1972',
        'Birth Year': '1972',
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Thick British Accent',
        'Height(ft)': '6.2', 
        'Weight(lbs)': '211.0',
        'Zodiac Sign': 'Virgo',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Hailee Steinfeld',
        'Sex': 'Female',
        'DOB': '12/11/1996,
        'Birth Year': '1996',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': ,
        'Height(ft)': '5.6',
        'Weight(lbs)': '130',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'John Stamos',
        'Sex': 'Male',
        'DOB': '8/9/1963',
        'Birth Year': '1963',
        'Eye Color': 'Blue',
        'Hair Color':'Brown',
        'Distinctive Features': 'Broad Smile',
        'Height(ft)': '6.0',
        'Weight(lbs)': '174.0',
        'Zodiac Sign': 'Leo',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Anna Popplewell',
        'Sex': 'Female',
        'DOB': '12/16/1988',
        'Birth Year': '1988',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Full Lips',
        'Height(ft)': '5.3',
        'Weight(lbs)': '119.0',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Tyler Blackburn',
        'Sex': 'Male',
        'DOB': '10/12/1986',
        'Birth Year': '1986',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Long Brown Hair',
        'Height(ft)': '5.10',
        'Weight(lbs)': '157.0',
        'Zodiac Sign': 'Libra',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'AnnaSophia Robb',
        'Sex': 'Female',
        'DOB': '12/08/1993',
        'Birth Year': '1993',
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Beautiful Eyes' ,
        'Height(ft)': '5.0',
        'Weight(lbs)': '108.0', 
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Bradley Cooper',
        'Sex': 'Male',
        'DOB': '1/5/1975',
        'Birth Year': '1975',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Piercing Blue Eyes',
        'Height(ft)': '6.1',
        'Weight(lbs)': '183.0',
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Nicole Kidman',
        'Sex': 'Female',
        'DOB': '6/20/1967',
        'Birth Year': '1967',
        'Eye Color': 'Blue',
        'Hair Color': 'Red',
        'Distinctive Features': 'Statuesque',
        'Height(ft)': '5.11',
        'Weight(lbs)': '140.0',
        'Zodiac Sign': 'Gemini',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Tom Welling',
        'Sex': 'Male',
        'DOB': '4/26/1977',
        'Birth Year': '1977',
        'Eye Color': 'Blue' ,
        'Hair Color': 'Brown',
        'Distinctive Features': 'Squared Jawline' ,
        'Height(ft)': '6.2',
        'Weight(lbs)': '198.0',
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Mercedes Mason',
        'Sex': 'Female',
        'DOB': '1/13/1983',
        'Birth Year': '1983',
        'Eye Color': "Blue",
        'Hair Color': "Brown",
        'Distinctive Features': "Beautiful Smile",
        'Height(ft)': '5.3',
        'Weight(lbs)': '126.0',
        'Zodiac Sign': 'Capricorn',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Jesse Williams',
        'Sex': 'Male',
        'DOB': '11/6/1981',
        'Birth Year': '1981',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Good Looks',
        'Height(ft)': '5.11', 
        'Weight(lbs)': '175.0',
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Kristen Stewart',
        'Sex': 'Female',
        'DOB': '4/21/1990', 
        'Birth Year': '1990',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Bedroom Eyes',
        'Height(ft)': '5.06',
        'Weight(lbs)': '133.0',
        'Zodiac Sign': 'Taurus',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Joe Manganiello',
        'Sex': 'Male',
        'DOB': '10/24/1976',
        'Birth Year': '1976',
        'Eye Color': 'Brown',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Great Muscular Body',
        'Height(ft)': '6.1'
        'Weight(lbs)': '205.0',
        'Zodiac Sign': 'Scorpio',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Julianne Moore',
        'Sex': 'Female',
        'DOB': '7/3/1960',
        'Birth Year': '1960',
        'Eye Color': 'Blue',
        'Hair Color': 'Red',
        'Distinctive Features': "Stunning Beatiful Smile",
        'Height(ft)': '5.3',
        'Weight(lbs)': '128.0',
        'Zodiac Sign': 'Cancer',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'John Boyega',
        'Sex': 'Male',
        'DOB': '12/17/1992',
        'Birth Year': '1992',
        'Eye Color': 'Brown',
        'Hair Color': 'Black',
        'Distinctive Features': 'Great Build',
        'Height(ft)': '5.10',
        'Weight(lbs)': '179.0',
        'Zodiac Sign': 'Sagittarius',
        'Tattoo Body Art': 'Yes'
    },

    {
        'Name': 'Kate Winslet',
        'Sex': 'Female',
        'DOB': '10/5/1975',
        'Birth Year': '1975',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Beautiful Smile',
        'Height(ft)': '5.6',
        'Weight(lbs)': '139.0',
        'Zodiac Sign': 'Libra',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Garrett Hedlund',
        'Sex': 'Male',
        'DOB': '9/3/1984',
        'Birth Year': '1984',
        'Eye Color': 'Blue',
        'Hair Color': 'Blonde',
        'Distinctive Features': 'Beautiful Eyes',
        'Height(ft)': '6.2',
        'Weight(lbs)': '201.0',
        'Zodiac Sign': 'Virgo',
        'Tattoo Body Art': 'No'
    },

    {
        'Name': 'Jennifer Aniston',
        'Sex': 'Female',
        'DOB': '2/11/1969',
        'Birth Year': '1969',
        'Eye Color': 'Blue',
        'Hair Color': 'Brown',
        'Distinctive Features': 'Gorgeous Hair',
        'Height(ft)': '5.4',
        'Weight(lbs)': '117.0',
        'Zodiac Sign': 'Aquarius',
        'Tattoo Body Art':'No'
    },

]

celeb_df = pd.DataFrame.from_dict(celeb_dict)  
celeb_df.head()
# Out:
#                   Name     Sex         DOB  Birth Year Eye Color Hair Color  \
# 0     Kerry Washington  Female  01/31/1977        1977     Brown      Black
# 1        Jensen Ackles    Male  03/01/1978        1978     Green      Brown
# 2       Shay Mitchell   Female  04/10/1987        1987     Brown      Black
# 3      Ian Somerhalder    Male  12/08/1978        1978      Blue      Brown
# 4  Alycia Debnam-Carey  Female  07/20/1993        1993     Green      Brown
#
#   Distinctive Features  Height(ft)  Weight(lbs)  Zodiac Sign Tattoo Body Art
# 0                 Lips         5.4        117.0     Aquarius              No
# 1                 Eyes         6.1        183.0       Pisces              No
# 2                 Hair         5.7        132.0        Aries              No
# 3                 Eyes         5.9        165.5  Sagittarius              No
# 4                 Lips         5.7        121.0       Cancer              No

# %%
import requests
url = 'http://127.0.0.1:5000/api/v1.0/hot'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data
# Out:
# [{'Name': 'Kerry Washington',
#   'Sex': 'Female',
#   'DOB': '01/31/1977',
#   'Birth Year': 1977,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Black',
#   'Distinctive Features': 'Lips',
#   'Height(ft)': 5.4,
#   'Weight(lbs)': 117.0,
#   'Zodiac Sign': 'Aquarius',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Jensen Ackles',
#   'Sex': 'Male',
#   'DOB': '03/01/1978',
#   'Birth Year': 1978,
#   'Eye Color': 'Green',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 6.1,
#   'Weight(lbs)': 183.0,
#   'Zodiac Sign': 'Pisces',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Shay Mitchell ',
#   'Sex': 'Female',
#   'DOB': '04/10/1987',
#   'Birth Year': 1987,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Black',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 132.0,
#   'Zodiac Sign': 'Aries',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Ian Somerhalder',
#   'Sex': 'Male',
#   'DOB': '12/08/1978',
#   'Birth Year': 1978,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.9,
#   'Weight(lbs)': 165.5,
#   'Zodiac Sign': 'Sagittarius',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Alycia Debnam-Carey',
#   'Sex': 'Female',
#   'DOB': '07/20/1993',
#   'Birth Year': 1993,
#   'Eye Color': 'Green',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Lips',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 121.0,
#   'Zodiac Sign': 'Cancer',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Ryan Gosling',
#   'Sex': 'Male',
#   'DOB': '11/12/1980',
#   'Birth Year': 1980,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Blonde',
#   'Distinctive Features': 'Jawline',
#   'Height(ft)': 6.0,
#   'Weight(lbs)': 172.0,
#   'Zodiac Sign': 'Scorpio',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Ruby Rose',
#   'Sex': 'Female',
#   'DOB': '03/20/1986',
#   'Birth Year': 1986,
#   'Eye Color': 'Green',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 128.0,
#   'Zodiac Sign': 'Pisces',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Ashton Kutcher',
#   'Sex': 'MAle',
#   'DOB': '02/07/1978',
#   'Birth Year': 1978,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Jawline',
#   'Height(ft)': 6.2,
#   'Weight(lbs)': 176.0,
#   'Zodiac Sign': 'Aquarius',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Kate Upton',
#   'Sex': 'Female',
#   'DOB': '07/10/1992',
#   'Birth Year': 1992,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Blonde',
#   'Distinctive Features': 'Lips',
#   'Height(ft)': 5.1,
#   'Weight(lbs)': 156.5,
#   'Zodiac Sign': 'Gemini',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Ricky Whittle',
#   'Sex': 'Male',
#   'DOB': '12/31/1981',
#   'Birth Year': 1981,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Black',
#   'Distinctive Features': 'Muscular',
#   'Height(ft)': 6.1,
#   'Weight(lbs)': 200.5,
#   'Zodiac Sign': 'Capricorn',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Jessica Biel',
#   'Sex': 'Female',
#   'DOB': '03/03/1982',
#   'Birth Year': 1982,
#   'Eye Color': 'Hazel',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 121.0,
#   'Zodiac Sign': 'Pisces',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Jason Momoa',
#   'Sex': 'male',
#   'DOB': '08/01/1979',
#   'Birth Year': 1979,
#   'Eye Color': 'Green',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Muscular',
#   'Height(ft)': 6.4,
#   'Weight(lbs)': 234.0,
#   'Zodiac Sign': 'Leo',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Marie Avgeropoulos',
#   'Sex': 'Female',
#   'DOB': '06/17/1986',
#   'Birth Year': 1986,
#   'Eye Color': 'Green',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.5,
#   'Weight(lbs)': 121.0,
#   'Zodiac Sign': ' Gemini',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Stephen Amell',
#   'Sex': 'Male',
#   'DOB': '05/08/1981',
#   'Birth Year': 1981,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Muscular',
#   'Height(ft)': 6.1,
#   'Weight(lbs)': 182.0,
#   'Zodiac Sign': 'Taurus',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Kate Hudson',
#   'Sex': 'Female',
#   'DOB': '04/19/1979',
#   'Birth Year': 1979,
#   'Eye Color': 'Green',
#   'Hair Color': 'Blonde',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 5.6,
#   'Weight(lbs)': 121.0,
#   'Zodiac Sign': 'Aries',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Chace Crawford',
#   'Sex': 'Male',
#   'DOB': '07/18/1985',
#   'Birth Year': 1985,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 6.0,
#   'Weight(lbs)': 175.0,
#   'Zodiac Sign': 'Cancer',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Olivia Wilde',
#   'Sex': 'Female',
#   'DOB': '03/10/1984',
#   'Birth Year': 1984,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 115.0,
#   'Zodiac Sign': 'Pisces',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Michael Fassbender',
#   'Sex': 'Male',
#   'DOB': '04/02/1977',
#   'Birth Year': 1977,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Jawline',
#   'Height(ft)': 6.0,
#   'Weight(lbs)': 174.0,
#   'Zodiac Sign': 'Aries',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Daisy Ridley',
#   'Sex': 'Female',
#   'DOB': '04/10/1992',
#   'Birth Year': 1992,
#   'Eye Color': 'Hazel',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 121.0,
#   'Zodiac Sign': 'Aries',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Chris Pine',
#   'Sex': 'Male',
#   'DOB': '08/26/1980',
#   'Birth Year': 1980,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 6.0,
#   'Weight(lbs)': 172.0,
#   'Zodiac Sign': 'Virgo',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Cate Blanchett',
#   'Sex': 'Female',
#   'DOB': '05/14/1969',
#   'Birth Year': 1969,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Blonde',
#   'Distinctive Features': 'Cheekbones',
#   'Height(ft)': 5.8,
#   'Weight(lbs)': 130.0,
#   'Zodiac Sign': 'Taurus',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Gerard Butler',
#   'Sex': 'Male',
#   'DOB': '11/13/1969',
#   'Birth Year': 1969,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 6.2,
#   'Weight(lbs)': 187.5,
#   'Zodiac Sign': 'Scorpio',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Emma Watson',
#   'Sex': 'Female',
#   'DOB': '04/15/1990',
#   'Birth Year': 1990,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.5,
#   'Weight(lbs)': 117.0,
#   'Zodiac Sign': 'Aries',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Luke Evans',
#   'Sex': 'Male',
#   'DOB': '04/15/1979',
#   'Birth Year': 1979,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Black',
#   'Distinctive Features': 'Personality',
#   'Height(ft)': 6.0,
#   'Weight(lbs)': 174.0,
#   'Zodiac Sign': 'Aries',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Penélope Cruz',
#   'Sex': 'Female',
#   'DOB': '04/28/1974',
#   'Birth Year': 1974,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Lips',
#   'Height(ft)': 5.6,
#   'Weight(lbs)': 137.0,
#   'Zodiac Sign': 'Taurus',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Tina Turner',
#   'Sex': 'Female',
#   'DOB': '11/26/1939',
#   'Birth Year': 1939,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Legs',
#   'Height(ft)': 5.4,
#   'Weight(lbs)': 129.0,
#   'Zodiac Sign': 'Sagittarius',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Brooke Shields',
#   'Sex': 'Female',
#   'DOB': '05/31/1965',
#   'Birth Year': 1965,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 6.0,
#   'Weight(lbs)': 154.0,
#   'Zodiac Sign': 'Gemini',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Whitney Houston',
#   'Sex': 'Female',
#   'DOB': '08/09/1963',
#   'Birth Year': 1963,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Chin',
#   'Height(ft)': 5.6,
#   'Weight(lbs)': 134.5,
#   'Zodiac Sign': 'Leo',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Belinda Carlisle',
#   'Sex': 'Female',
#   'DOB': '08/17/1958',
#   'Birth Year': 1958,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Lips',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 137.0,
#   'Zodiac Sign': 'Leo',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Lisa Bonet',
#   'Sex': 'Female',
#   'DOB': '11/16/1967',
#   'Birth Year': 1967,
#   'Eye Color': 'Black',
#   'Hair Color': 'Black',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 5.2,
#   'Weight(lbs)': 117.0,
#   'Zodiac Sign': 'Scorpio',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Marilyn Monroe',
#   'Sex': 'Female',
#   'DOB': '06/01/1926',
#   'Birth Year': 1926,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Blonde',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 5.5,
#   'Weight(lbs)': 119.0,
#   'Zodiac Sign': 'Gemini',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Richard Gere',
#   'Sex': 'Male',
#   'DOB': '08/31/1949',
#   'Birth Year': 1949,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Black',
#   'Distinctive Features': 'Nose',
#   'Height(ft)': 5.1,
#   'Weight(lbs)': 174.0,
#   'Zodiac Sign': 'Virgo',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Antonio Bandera',
#   'Sex': 'Male',
#   'DOB': '08/10/1960',
#   'Birth Year': 1960,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Gray',
#   'Distinctive Features': 'Voice',
#   'Height(ft)': 5.8,
#   'Weight(lbs)': 167.5,
#   'Zodiac Sign': 'Leo',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Bill Clinton',
#   'Sex': 'Male',
#   'DOB': '08/19/1946',
#   'Birth Year': 1946,
#   'Eye Color': 'Gray',
#   'Hair Color': 'Gray',
#   'Distinctive Features': 'Voice',
#   'Height(ft)': 6.2,
#   'Weight(lbs)': 192.0,
#   'Zodiac Sign': 'Leo',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Selena Quintanilla',
#   'Sex': 'Female',
#   'DOB': '04/16/1971',
#   'Birth Year': 1971,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Black',
#   'Distinctive Features': 'Lips',
#   'Height(ft)': 5.5,
#   'Weight(lbs)': 126.0,
#   'Zodiac Sign': 'Aries',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Jamie Dornan',
#   'Sex': 'Male',
#   'DOB': '05/01/1982',
#   'Birth Year': 1982,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 6.0,
#   'Weight(lbs)': 170.0,
#   'Zodiac Sign': 'Taurus',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Keira Knightley',
#   'Sex': 'Female',
#   'DOB': '03/26/1985',
#   'Birth Year': 1985,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 119.0,
#   'Zodiac Sign': 'Aries',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Chris Evans',
#   'Sex': 'Male',
#   'DOB': '06/13/1981',
#   'Birth Year': 1981,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Muscular',
#   'Height(ft)': 6.0,
#   'Weight(lbs)': 176.5,
#   'Zodiac Sign': 'Gemini',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Felicity Jones',
#   'Sex': 'Female',
#   'DOB': '10/17/1983',
#   'Birth Year': 1983,
#   'Eye Color': 'Green',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Teeth',
#   'Height(ft)': 5.3,
#   'Weight(lbs)': 121.0,
#   'Zodiac Sign': 'Libra',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Jonathan Rhys Meyers',
#   'Sex': 'Male',
#   'DOB': '07/27/1977',
#   'Birth Year': 1977,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.9,
#   'Weight(lbs)': 159.0,
#   'Zodiac Sign': 'Leo',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Megan Fox',
#   'Sex': 'Female',
#   'DOB': '05/16/1986',
#   'Birth Year': 1986,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.4,
#   'Weight(lbs)': 114.0,
#   'Zodiac Sign': 'Taurus',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Alexander Dreymon',
#   'Sex': 'Male',
#   'DOB': '02/07/1983',
#   'Birth Year': 1983,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.1,
#   'Weight(lbs)': 172.0,
#   'Zodiac Sign': 'Aquarius',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Monroe Hayden',
#   'Sex': 'Female',
#   'DOB': '11/08/1988',
#   'Birth Year': 1988,
#   'Eye Color': 'Gray',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.4,
#   'Weight(lbs)': 114.0,
#   'Zodiac Sign': 'Scorpio',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Douglas Booth',
#   'Sex': 'Male',
#   'DOB': '07/09/1992',
#   'Birth Year': 1992,
#   'Eye Color': 'Hazel',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Jawline',
#   'Height(ft)': 6.1,
#   'Weight(lbs)': 170.0,
#   'Zodiac Sign': 'Cancer',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Kristin Kreuk',
#   'Sex': 'Female',
#   'DOB': '12/30/1982',
#   'Birth Year': 1982,
#   'Eye Color': 'Hazel',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.4,
#   'Weight(lbs)': 115.0,
#   'Zodiac Sign': 'Capricorn',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Colin Farrell',
#   'Sex': 'Male',
#   'DOB': '05/31/1976',
#   'Birth Year': 1976,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Eyebrows',
#   'Height(ft)': 5.1,
#   'Weight(lbs)': 176.0,
#   'Zodiac Sign': 'Gemini',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Katie Cassidy',
#   'Sex': 'Female',
#   'DOB': '11/25/1986',
#   'Birth Year': 1986,
#   'Eye Color': 'Green',
#   'Hair Color': 'Blond',
#   'Distinctive Features': 'Lips',
#   'Height(ft)': 5.6,
#   'Weight(lbs)': 119.0,
#   'Zodiac Sign': 'Sagittarius',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Alex Pettyfer',
#   'Sex': 'Male',
#   'DOB': '04/10/1990',
#   'Birth Year': 1990,
#   'Eye Color': 'Green',
#   'Hair Color': 'Blond',
#   'Distinctive Features': 'Body',
#   'Height(ft)': 5.11,
#   'Weight(lbs)': 174.0,
#   'Zodiac Sign': 'Aries',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Anna Kendrick',
#   'Sex': 'Female',
#   'DOB': '08/09/1985',
#   'Birth Year': 1985,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Smile',
#   'Height(ft)': 5.2,
#   'Weight(lbs)': 106.0,
#   'Zodiac Sign': 'Leo',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Jeffrey Dean Morgan',
#   'Sex': 'Male',
#   'DOB': '04/22/1966',
#   'Birth Year': 1966,
#   'Eye Color': 'Hazel',
#   'Hair Color': 'Gray',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 6.2,
#   'Weight(lbs)': 183.0,
#   'Zodiac Sign': 'Taurus',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Jennifer Lawrence',
#   'Sex': 'Female',
#   'DOB': '08/15/1990',
#   'Birth Year': 1990,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Blond',
#   'Distinctive Features': 'Smile',
#   'Height(ft)': 5.9,
#   'Weight(lbs)': 139.0,
#   'Zodiac Sign': 'Leo',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Liam Hemsworth',
#   'Sex': 'Male',
#   'DOB': '01/13/1990',
#   'Birth Year': 1990,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Blond',
#   'Distinctive Features': 'Body',
#   'Height(ft)': 6.3,
#   'Weight(lbs)': 196.0,
#   'Zodiac Sign': 'Capricorn',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Emma Stone',
#   'Sex': 'Female',
#   'DOB': '11/06/1988',
#   'Birth Year': 1988,
#   'Eye Color': 'Green',
#   'Hair Color': 'Blond',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 5.6,
#   'Weight(lbs)': 115.0,
#   'Zodiac Sign': 'Scorpio',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Frank Dillane',
#   'Sex': 'Male',
#   'DOB': '04/21/1991',
#   'Birth Year': 1991,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 5.11,
#   'Weight(lbs)': 163.0,
#   'Zodiac Sign': 'Taurus',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Katie McGrath',
#   'Sex': 'Female',
#   'DOB': '10/24/1983',
#   'Birth Year': 1983,
#   'Eye Color': 'Green',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Teeth',
#   'Height(ft)': 5.5,
#   'Weight(lbs)': 135.0,
#   'Zodiac Sign': 'Scorpio',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Tom Cruise',
#   'Sex': 'Male',
#   'DOB': '07/03/1962',
#   'Birth Year': 1962,
#   'Eye Color': 'Green',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Teeth',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 148.0,
#   'Zodiac Sign': 'Cancer',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Sarah Paulson',
#   'Sex': 'Female',
#   'DOB': '12/17/1974',
#   'Birth Year': 1974,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Blond',
#   'Distinctive Features': 'Voice',
#   'Height(ft)': 5.6,
#   'Weight(lbs)': 119.0,
#   'Zodiac Sign': 'Sagittarius',
#   'Tattoo Body Art': 'Yes'},
#  {'Name': 'Keanu Reeves',
#   'Sex': 'Male',
#   'DOB': '09/02/1964',
#   'Birth Year': 1964,
#   'Eye Color': 'Hazel',
#   'Hair Color': 'Black',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 6.1,
#   'Weight(lbs)': 185.0,
#   'Zodiac Sign': 'Virgo',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Cameron Diaz',
#   'Sex': 'Female',
#   'DOB': '08/30/1972',
#   'Birth Year': 1972,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Blond',
#   'Distinctive Features': 'Legs',
#   'Height(ft)': 5.9,
#   'Weight(lbs)': 128.0,
#   'Zodiac Sign': 'Virgo',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'George Clooney',
#   'Sex': 'Male',
#   'DOB': '05/06/1961',
#   'Birth Year': 1961,
#   'Eye Color': 'Brown',
#   'Hair Color': 'Gray',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 5.11,
#   'Weight(lbs)': 172.0,
#   'Zodiac Sign': 'Taurus',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Audrey Hepburn',
#   'Sex': 'Female',
#   'DOB': '05/04/1929',
#   'Birth Year': 1929,
#   'Eye Color': 'Hazel',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 119.0,
#   'Zodiac Sign': 'Taurus',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Grace Kelly',
#   'Sex': 'Female',
#   'DOB': '11/12/1929',
#   'Birth Year': 1929,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Blond',
#   'Distinctive Features': 'Hair',
#   'Height(ft)': 5.6,
#   'Weight(lbs)': 121.0,
#   'Zodiac Sign': 'Scorpio',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Elizabeth Taylor',
#   'Sex': 'Female',
#   'DOB': '02/27/1932',
#   'Birth Year': 1932,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Black',
#   'Distinctive Features': 'Eyes',
#   'Height(ft)': 5.4,
#   'Weight(lbs)': 183.0,
#   'Zodiac Sign': 'Pisces',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'Marlon Brando',
#   'Sex': 'Male',
#   'DOB': '04/03/1924',
#   'Birth Year': 1924,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Jawline',
#   'Height(ft)': 5.9,
#   'Weight(lbs)': 242.0,
#   'Zodiac Sign': 'Aries',
#   'Tattoo Body Art': 'No'},
#  {'Name': 'James Dean',
#   'Sex': 'Male',
#   'DOB': '02/08/1931',
#   'Birth Year': 1931,
#   'Eye Color': 'Blue',
#   'Hair Color': 'Brown',
#   'Distinctive Features': 'Jawline',
#   'Height(ft)': 5.7,
#   'Weight(lbs)': 139.0,
#   'Zodiac Sign': 'Aquarius',
#   'Tattoo Body Art': 'No'}]
